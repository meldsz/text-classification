# %% [markdown]
# ## COMP47670 - Assignment 2
# **Student Name: Meleesha Mayola Dsouza, Nikil Mohan**<br>
# **Student Number: 18200024, 18200037**

# %%
# Import the required libraries
import os
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Selecting review categories
#
# For the purpose of this assignment we have chosen the following categories:
# 1. Automotive
# 2. Health and Medical

# %%
endpoint = 'http://mlg.ucd.ie/modules/yalp/'

def extract_page(url):
    response = requests.get(url)
    data = response.text

    soup = BeautifulSoup(data,'html.parser')
    print(soup.prettify())
    return soup

def extract_reviews(url):
    soup = extract_page(url)

    reviews_block = soup.findAll("div", { "class" : "review" })
    review_list =[]
    for reviews in reviews_block:
        review = {}
        star = reviews.find('img')
        #review["stars"] = star.get('alt').split('-')[0]
        review["comments"] = reviews.find("p", { "class" : "text" }).get_text()
        review["rating"] = 'positive' if int(star.get('alt').split('-')[0]) > 4 else 'negative'
        review_list.append(review)
        
    return review_list

def extract_data(url):
    soup = extract_page(url)

    links = soup.find_all('a')
    review_list =[]
    for link in links:
        url = endpoint + link.get('href')
        review = extract_reviews(url)
        review_list = review_list+review
        #review_list.append(review)
    return review_list
        
def create_database(category, 
                    reviews):
    header = reviews[0].keys()
    with open(category, 'w',newline='', encoding="utf-8") as output_file:
        dict_writer = csv.DictWriter(output_file, header)
        dict_writer.writeheader()
        dict_writer.writerows(reviews)

# %% [markdown]
# Create database for category A, Health and medical reviews

# %%
# extract Health and medical reviews
url = endpoint + 'health_medical_list.html'
review_list = extract_data(url)
create_database('Category_A.csv', review_list)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="noindex" name="robots"/>
#   <meta content="Content on this site is posted for teaching purposes only. Original data is from yelp.com" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Yalp — Fresh Reviews for Health and medical
#   </title>
#   <link href="images/favicon.ico" rel="shortcut icon"/>
#   <!-- Bootstrap core CSS -->
#   <link href="assets/css/bootstrap.css" rel="stylesheet"/>
#   <!-- Custom styles for this template -->
#   <link href="assets/css/style.css" rel="stylesheet"/>
#   <link href="assets/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="assets/js/modernizr.js">
#   </script>
#  </head>
#  <body>
#   <div class="container mtb">
#    <div class="row">
#     <div class="col-md-12">
#      <h3 class="info">
#       Yalp — Fresh Reviews for Health and medical
#      </h3>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-10" name="main">
#      <h5>
#       List of all 122 businesses in the category
#       <i>
#        Health and medical
#       </i>
#       :
#      </h5>
#      <p>
#       <h6>
#        1.
#        <a href="reviews_tI0-USBAFWXpQ9Es6gpKXg.html">
#         AZ Dental Wellness
#        </a>
#       </h6>
#       3014 N Hayden Rd, Ste 104, Scottsdale, AZ
#       <br/>
#       Dentists, Teeth Whitening, General Dentistry, Pediatric Dentists, Endodontists, Cosmetic Dentists, Beauty &amp; Spas, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        2.
#        <a href="reviews_z30sgua7-gO8eMfWT-ViTQ.html">
#         ActiveForever
#        </a>
#       </h6>
#       9299 W Olive Ave, Ste 604, Peoria, AZ
#       <br/>
#       Medical Supplies, Food, Health Markets, Physical Therapy, Health &amp; Medical, Specialty Food, Shopping, Home Health Care
#      </p>
#      <p>
#       <h6>
#        3.
#        <a href="reviews_V_DXV9qg7QtG1r58aUJOrQ.html">
#         Alcohol Awareness Training
#        </a>
#       </h6>
#       3110 E Sunset Rd, Ste B, Las Vegas, NV
#       <br/>
#       Rehabilitation Center, Special Education, Education, Adult Education, Health &amp; Medical, Specialty Schools
#      </p>
#      <p>
#       <h6>
#        4.
#        <a href="reviews_z40G19e_XZh_XML0-W2mKw.html">
#         Angel Hands
#        </a>
#       </h6>
#       4480 Paradise Rd, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Reflexology
#      </p>
#      <p>
#       <h6>
#        5.
#        <a href="reviews_VSM4SB7yRHzXqwPv9JApFw.html">
#         Apex Physical Therapy
#        </a>
#       </h6>
#       6320 W Union Hills Dr, Ste 265, Glendale, AZ
#       <br/>
#       Physical Therapy, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        6.
#        <a href="reviews_wrte8YYJtPQK4zccENm_Gw.html">
#         Arch Liberty Village Dental Centre
#        </a>
#       </h6>
#       51 East Liberty Street, Unit 2, Toronto, ON
#       <br/>
#       Health &amp; Medical, Dentists, Oral Surgeons, Periodontists, General Dentistry, Endodontists
#      </p>
#      <p>
#       <h6>
#        7.
#        <a href="reviews_ZUZBA9EBWfML5aSJmH7yvw.html">
#         Arizona Organix
#        </a>
#       </h6>
#       5301 W Glendale Ave, Glendale, AZ
#       <br/>
#       Health &amp; Medical, Cannabis Clinics
#      </p>
#      <p>
#       <h6>
#        8.
#        <a href="reviews_p36XSjsfgvEYE_lZHU4nrg.html">
#         Aspen Dental
#        </a>
#       </h6>
#       4602 E Washington Ave, Madison, WI
#       <br/>
#       Health &amp; Medical, Dentists, Cosmetic Dentists, General Dentistry, Oral Surgeons
#      </p>
#      <p>
#       <h6>
#        9.
#        <a href="reviews_4QV9lsViwEHmy07Vqv99ew.html">
#         Beyond Expectation Dental
#        </a>
#       </h6>
#       1425 W Southern Ave, Ste 15, Tempe, AZ
#       <br/>
#       General Dentistry, Endodontists, Cosmetic Dentists, Dentists, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        10.
#        <a href="reviews_p9xhVRcI2jHgwPH-OYJvFQ.html">
#         Body Works By Joel
#        </a>
#       </h6>
#       284 S Dobson Rd, Chandler, AZ
#       <br/>
#       Massage Therapy, Massage, Beauty &amp; Spas, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        11.
#        <a href="reviews_sQqn2UXb9NqDruKmmBhvuw.html">
#         Boracay Massage
#        </a>
#       </h6>
#       9340 W Tropicana Ave, Las Vegas, NV
#       <br/>
#       Massage, Massage Therapy, Beauty &amp; Spas, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        12.
#        <a href="reviews_NNNZFhecyADXs1yCq9GPaA.html">
#         Bridgeland Dental Care
#        </a>
#       </h6>
#       939 General Avenue NE, Calgary, AB
#       <br/>
#       Cosmetic Dentists, Dentists, General Dentistry, Health &amp; Medical, Orthodontists
#      </p>
#      <p>
#       <h6>
#        13.
#        <a href="reviews_NVHuUK206x2E6KcJJX775g.html">
#         Briggs Family Dentistry
#        </a>
#       </h6>
#       6920 E Shea Blvd, Ste 201, Scottsdale, AZ
#       <br/>
#       Cosmetic Dentists, General Dentistry, Health &amp; Medical, Dentists
#      </p>
#      <p>
#       <h6>
#        14.
#        <a href="reviews_FT5bvXUI_1pvVdPy2psJPQ.html">
#         Bright Now! Dental
#        </a>
#       </h6>
#       1473 N Dysart Rd, Ste 105, Avondale, AZ
#       <br/>
#       Health &amp; Medical, Orthodontists, General Dentistry, Dentists, Cosmetic Dentists
#      </p>
#      <p>
#       <h6>
#        15.
#        <a href="reviews_uC2l00w4_JDNepoaCv3afA.html">
#         Brown Road Family Medicine
#        </a>
#       </h6>
#       2310 E Brown Rd, Mesa, AZ
#       <br/>
#       Doctors, Family Practice, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        16.
#        <a href="reviews_RKVINOHlNgivItzqEAc1mQ.html">
#         Camelback Medical Centers
#        </a>
#       </h6>
#       4432 N Miller Rd, Ste 102, Scottsdale, AZ
#       <br/>
#       Chiropractors, Medical Centers, Weight Loss Centers, Physical Therapy, Doctors, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        17.
#        <a href="reviews_eumrCpNIoSepFGiPqrX85Q.html">
#         Carolina Sports Clinic
#        </a>
#       </h6>
#       985 Market St, Ste 201, Fort Mill, SC
#       <br/>
#       Physical Therapy, Health &amp; Medical, Doctors, Chiropractors, Sports Medicine
#      </p>
#      <p>
#       <h6>
#        18.
#        <a href="reviews_wipSpwLvMnDDaMwhLNj-1w.html">
#         Center For Dermatology &amp; Plastic Surgery
#        </a>
#       </h6>
#       11209 North Tatum Blvd, Ste 175, Phoenix, AZ
#       <br/>
#       Doctors, Skin Care, Dermatologists, Beauty &amp; Spas, Health &amp; Medical, Cosmetic Surgeons
#      </p>
#      <p>
#       <h6>
#        19.
#        <a href="reviews_9SqXsbePo1M0xj_9KFAQqw.html">
#         Chaparral Dental
#        </a>
#       </h6>
#       7904 E Chaparral Rd, Ste 109, Scottsdale, AZ
#       <br/>
#       Dentists, General Dentistry, Health &amp; Medical, Cosmetic Dentists, Pediatric Dentists
#      </p>
#      <p>
#       <h6>
#        20.
#        <a href="reviews_MrxA-fbbiBJIBl2569dTRg.html">
#         Coast Dental
#        </a>
#       </h6>
#       3163 N Rainbow Blvd, Las Vegas, NV
#       <br/>
#       Periodontists, Dentists, Oral Surgeons, Health &amp; Medical, General Dentistry
#      </p>
#      <p>
#       <h6>
#        21.
#        <a href="reviews_JvUlnK9j47e7U3VtWwE6Rg.html">
#         Coco Reflexology Massage
#        </a>
#       </h6>
#       10575 W Indian School Rd, Ste E-110, Avondale, AZ
#       <br/>
#       Health &amp; Medical, Day Spas, Massage, Reflexology, Beauty &amp; Spas
#      </p>
#      <p>
#       <h6>
#        22.
#        <a href="reviews_X-1UxWNtnFvqKWFyTs2TRw.html">
#         Concentra Medical Centers
#        </a>
#       </h6>
#       149 N Gibson Rd, Henderson, NV
#       <br/>
#       Health &amp; Medical, Medical Centers, Physical Therapy
#      </p>
#      <p>
#       <h6>
#        23.
#        <a href="reviews_IhPOQdaC0ASK36Z569fheQ.html">
#         Couples Massage Las Vegas
#        </a>
#       </h6>
#       Las Vegas, NV
#       <br/>
#       Beauty &amp; Spas, Nightlife, Health &amp; Medical, Massage, Lounges, Day Spas, Bars, Massage Therapy
#      </p>
#      <p>
#       <h6>
#        24.
#        <a href="reviews_FUCJRACt-g0ACqL0u_1p-A.html">
#         Cullimore Family Dentistry
#        </a>
#       </h6>
#       2038 N Recker Rd, Mesa, AZ
#       <br/>
#       Dentists, Health &amp; Medical, General Dentistry, Cosmetic Dentists
#      </p>
#      <p>
#       <h6>
#        25.
#        <a href="reviews__c0arL_K3WiN2UlOwNUoXQ.html">
#         Cynthia J Price, MD
#        </a>
#       </h6>
#       6710 E Camelback Rd, Ste 220, Scottsdale, AZ
#       <br/>
#       Health &amp; Medical, Doctors, Dermatologists
#      </p>
#      <p>
#       <h6>
#        26.
#        <a href="reviews_HsMeo9W71akGBYhY2XBFxg.html">
#         Dani Dental Studio
#        </a>
#       </h6>
#       1243 E Broadway Rd, Ste 201, Tempe, AZ
#       <br/>
#       Cosmetic Dentists, Orthodontists, Health &amp; Medical, Dentists, General Dentistry
#      </p>
#      <p>
#       <h6>
#        27.
#        <a href="reviews_S1N2QL9M_b03c1wUWVsXHA.html">
#         David A Foggia, MD
#        </a>
#       </h6>
#       7040 Smoke Ranch Rd, Las Vegas, NV
#       <br/>
#       Doctors, Ear Nose &amp; Throat, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        28.
#        <a href="reviews_0RTYIoUN7rtnNSCo7uEdSg.html">
#         Dawn L Green, DDS
#        </a>
#       </h6>
#       3900 Paradise Rd, Ste 251, Las Vegas, NV
#       <br/>
#       Dentists, General Dentistry, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        29.
#        <a href="reviews_C5uWte569tr6pg9aNjXcJg.html">
#         DeNovo Clinic
#        </a>
#       </h6>
#       9330 W Sahara Ave, Ste 250, Las Vegas, NV
#       <br/>
#       Weight Loss Centers, Beauty &amp; Spas, Hair Removal, Nutritionists, Medical Spas, Acne Treatment, Laser Hair Removal, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        30.
#        <a href="reviews_idJTf2K64vA6LypyTiKC-Q.html">
#         DeRosa Medical
#        </a>
#       </h6>
#       9377 E Bell Rd, Ste 143, Scottsdale, AZ
#       <br/>
#       Internal Medicine, Health &amp; Medical, Osteopathic Physicians, Family Practice, Medical Centers, Weight Loss Centers, Doctors
#      </p>
#      <p>
#       <h6>
#        31.
#        <a href="reviews_T6zd-sjoKkPJ_jWDuurcWQ.html">
#         Desert Eye
#        </a>
#       </h6>
#       3200 S Rural Rd, Ste 1, Tempe, AZ
#       <br/>
#       Health &amp; Medical, Shopping, Optometrists, Eyewear &amp; Opticians
#      </p>
#      <p>
#       <h6>
#        32.
#        <a href="reviews_8SCuTbcjv4pph3Cbmo-wDA.html">
#         East Valley Tattoo Removal
#        </a>
#       </h6>
#       1712 E Guadalupe Rd, Ste 105, Tempe, AZ
#       <br/>
#       Doctors, Beauty &amp; Spas, Tattoo Removal, Health &amp; Medical, Skin Care
#      </p>
#      <p>
#       <h6>
#        33.
#        <a href="reviews_cnCCTB_UVZ4xrZ5UG2Fvgw.html">
#         Eastwind Dental
#        </a>
#       </h6>
#       2075 E Windmill Ln, Ste 110, Las Vegas, NV
#       <br/>
#       General Dentistry, Orthodontists, Endodontists, Health &amp; Medical, Dentists
#      </p>
#      <p>
#       <h6>
#        34.
#        <a href="reviews_nUR9_N_dl9bQ0K-7bNLJpQ.html">
#         Elante Spa
#        </a>
#       </h6>
#       6140 W Tropicana Ave, Ste C-2, Smith's Shopping Ctr, Las Vegas, NV
#       <br/>
#       Massage, Beauty &amp; Spas, Skin Care, Permanent Makeup, Health &amp; Medical, Massage Therapy, Day Spas
#      </p>
#      <p>
#       <h6>
#        35.
#        <a href="reviews_efAitWV-gizH9lFQwvm9XQ.html">
#         Freestone Chiropractic
#        </a>
#       </h6>
#       2500 E Southern Ave, Mesa, AZ
#       <br/>
#       Chiropractors, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        36.
#        <a href="reviews_WrkOKBHkRxhBVpX8qu7zDA.html">
#         Freshii
#        </a>
#       </h6>
#       1290 S Normal Ave, Tempe, AZ
#       <br/>
#       Specialty Food, Food, Mexican, Restaurants, Breakfast &amp; Brunch, Fast Food, Health Markets, Salad
#      </p>
#      <p>
#       <h6>
#        37.
#        <a href="reviews_XmbfbCSm-NmAvflusZJlIg.html">
#         Gnc
#        </a>
#       </h6>
#       20260 N 59th Ave, Glendale, AZ
#       <br/>
#       Shopping, Health Markets, Food, Vitamins &amp; Supplements, Specialty Food
#      </p>
#      <p>
#       <h6>
#        38.
#        <a href="reviews_Gu4W3BSBajnljGYXQOclHw.html">
#         Grabbagreen Gilbert
#        </a>
#       </h6>
#       75 E Rivulon Blvd, Ste 107, Gilbert, AZ
#       <br/>
#       Acai Bowls, Restaurants, Specialty Food, Food, Health Markets, Fast Food, Juice Bars &amp; Smoothies, Gluten-Free
#      </p>
#      <p>
#       <h6>
#        39.
#        <a href="reviews_ubC3XvGLxDi3QHlW2J1Q7w.html">
#         Green Spring SPA
#        </a>
#       </h6>
#       10718 Carmel Commons Blvd, Ste 220, Charlotte, NC
#       <br/>
#       Reflexology, Beauty &amp; Spas, Day Spas, Saunas, Massage, Massage Therapy, Health &amp; Medical, Traditional Chinese Medicine, Tui Na
#      </p>
#      <p>
#       <h6>
#        40.
#        <a href="reviews_2mINRT7Po-OOQvnurvoPeg.html">
#         Green Yoga
#        </a>
#       </h6>
#       209 Commercial Ave, Fl 2, Pittsburgh, PA
#       <br/>
#       Reiki, Shopping, Active Life, Cooking Classes, Beauty &amp; Spas, Fitness &amp; Instruction, Reflexology, Arts &amp; Crafts, Massage, Yoga, Health &amp; Medical, Nutritionists
#      </p>
#      <p>
#       <h6>
#        41.
#        <a href="reviews_HBWJcqC0NSYs_q1awML8FA.html">
#         Hi-Health Supermart - Chaparral Plaza Shopping Center
#        </a>
#       </h6>
#       7908 E Chaparral Rd, Ste 101, Chaparral Plaza Shopping Ctr, Scottsdale, AZ
#       <br/>
#       Vitamins &amp; Supplements, Specialty Food, Health Markets, Shopping, Food
#      </p>
#      <p>
#       <h6>
#        42.
#        <a href="reviews_sLOuVlFXdefItC3yMJ2ttg.html">
#         HonorHealth Urgent Care PLUS
#        </a>
#       </h6>
#       13843 N Tatum Blvd, Phoenix, AZ
#       <br/>
#       Health &amp; Medical, Urgent Care, Doctors, Hospitals
#      </p>
#      <p>
#       <h6>
#        43.
#        <a href="reviews_Z3QHUXXUq3ek9iJFe5BQew.html">
#         IV Revival/ Mobile Hydration Therapy
#        </a>
#       </h6>
#       Scottsdale, AZ
#       <br/>
#       Health &amp; Medical, IV Hydration
#      </p>
#      <p>
#       <h6>
#        44.
#        <a href="reviews_BOO8XZ5J8rLVGvOe4BnxNw.html">
#         Image Eye Care
#        </a>
#       </h6>
#       2789 Sunridge Heights Pkwy, Ste 110, Henderson, NV
#       <br/>
#       Shopping, Optometrists, Eyewear &amp; Opticians, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        45.
#        <a href="reviews_Vd1HOb0V8CvMH63nsT4NhQ.html">
#         In &amp; Out Chiropractic
#        </a>
#       </h6>
#       5099 W Dobbins Rd, Laveen Village, AZ
#       <br/>
#       Chiropractors, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        46.
#        <a href="reviews_v__Y_SUaotEG0tKae5NjLQ.html">
#         Innova Medical &amp; Spa
#        </a>
#       </h6>
#       1530 W Glendale Ave, Ste 106, Phoenix, AZ
#       <br/>
#       Beauty &amp; Spas, Cosmetic Surgeons, Pain Management, Medical Spas, Nutritionists, Naturopathic/Holistic, Doctors, Health &amp; Medical, Weight Loss Centers
#      </p>
#      <p>
#       <h6>
#        47.
#        <a href="reviews_4uHJ0IcUJZU4RkmOZSiXKw.html">
#         J. Woodson Dermatology &amp; Associates
#        </a>
#       </h6>
#       9020 W Cheyenne Ave, Ste 422, Las Vegas, NV
#       <br/>
#       Dermatologists, Health &amp; Medical, Laser Hair Removal, Hair Removal, Medical Centers, Beauty &amp; Spas, Skin Care, Doctors
#      </p>
#      <p>
#       <h6>
#        48.
#        <a href="reviews_URlo_ACUzi05DpV_FsWl0Q.html">
#         Jacobs &amp; Modaber, MD
#        </a>
#       </h6>
#       2870 S Maryland Pkwy, Las Vegas, NV
#       <br/>
#       Internal Medicine, Health &amp; Medical, Doctors
#      </p>
#      <p>
#       <h6>
#        49.
#        <a href="reviews_d4WbPFDGr_eQfb29H4UD6Q.html">
#         Joe W Pearson, DDS
#        </a>
#       </h6>
#       Phoenix, AZ
#       <br/>
#       Dentists, Health &amp; Medical, Professional Services, Orthodontists
#      </p>
#      <p>
#       <h6>
#        50.
#        <a href="reviews_Rq2rdq3Za9kfF-UE_x8VOA.html">
#         Judy's Body Waxing &amp; Harmonic Healing Center
#        </a>
#       </h6>
#       2226 S Rural Rd, Tempe, AZ
#       <br/>
#       Health &amp; Medical, Chiropractors, Beauty &amp; Spas, Acupuncture, Hair Removal, Massage
#      </p>
#      <p>
#       <h6>
#        51.
#        <a href="reviews_IpaYzqptT9lbxXmft9zdZw.html">
#         Julie Anne Castilla, MD
#        </a>
#       </h6>
#       9823 N 95th St, Ste 101, Scottsdale, AZ
#       <br/>
#       Health &amp; Medical, Doctors, Obstetricians &amp; Gynecologists
#      </p>
#      <p>
#       <h6>
#        52.
#        <a href="reviews_Il0YOKi4OPQVoHRIAlfeSg.html">
#         Katsur Dental
#        </a>
#       </h6>
#       9059 W Lake Pleasant Pkwy, Peoria, AZ
#       <br/>
#       Health &amp; Medical, Dentists
#      </p>
#      <p>
#       <h6>
#        53.
#        <a href="reviews_SymVMYeaZ43FEsb-zpR1Mg.html">
#         L'Oiseau Tonnerre
#        </a>
#       </h6>
#       501 Avenue Duluth E, MontrÃ©al, QC
#       <br/>
#       Shopping, Fashion, Health &amp; Medical, Shoe Stores, Reflexology
#      </p>
#      <p>
#       <h6>
#        54.
#        <a href="reviews_dRUGL1wNpxbr_I_N3FumsQ.html">
#         Lebowitz Dental Associates
#        </a>
#       </h6>
#       1277 E Missouri Ave, Ste 205, Phoenix, AZ
#       <br/>
#       Cosmetic Dentists, General Dentistry, Health &amp; Medical, Dentists
#      </p>
#      <p>
#       <h6>
#        55.
#        <a href="reviews__JMIWY7O4SQ2gCJeDM5mRg.html">
#         Legacy Women's Health
#        </a>
#       </h6>
#       8480 S Eastern Ave, Ste F, Las Vegas, NV
#       <br/>
#       Obstetricians &amp; Gynecologists, Doctors, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        56.
#        <a href="reviews_M1C-RK-wOKOm7EgvTA6qXg.html">
#         Loving Family Dental
#        </a>
#       </h6>
#       16838 E Palisades Blvd, Ste 111, Fountain Hills, AZ
#       <br/>
#       Health &amp; Medical, General Dentistry, Cosmetic Dentists, Dentists
#      </p>
#      <p>
#       <h6>
#        57.
#        <a href="reviews_Pre8gJoG16rRtCRb2UvVTQ.html">
#         M2 Medical Spa and Wellness
#        </a>
#       </h6>
#       8430 Rea Rd, Ste E, Charlotte, NC
#       <br/>
#       Medical Spas, Health &amp; Medical, Waxing, Beauty &amp; Spas, Rolfing, Spray Tanning, Massage Therapy, Hair Removal, Tanning
#      </p>
#      <p>
#       <h6>
#        58.
#        <a href="reviews_55VOvGFNYR0c72iEENfdag.html">
#         Magnificent Hands Center for Healing
#        </a>
#       </h6>
#       2055 E Windmill Ln, Ste 155, Las Vegas, NV
#       <br/>
#       Acupuncture, Massage, Fitness &amp; Instruction, Reflexology, Halotherapy, Skin Care, Reiki, Yoga, Health &amp; Medical, Massage Therapy, Active Life, Beauty &amp; Spas, Meditation Centers
#      </p>
#      <p>
#       <h6>
#        59.
#        <a href="reviews_k9aOBvsb2IrZ2UpDsZrnZw.html">
#         Massage Heights Northgate
#        </a>
#       </h6>
#       198A-495 36 Street Northeast, Calgary, AB
#       <br/>
#       Massage, Skin Care, Massage Therapy, Beauty &amp; Spas, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        60.
#        <a href="reviews_hJznCjsZAAt0RmVuJhlMyQ.html">
#         Michael S Kaplan, MD
#        </a>
#       </h6>
#       2645 W Horizon Ridge Pkwy, Ste 120, Henderson, NV
#       <br/>
#       Health &amp; Medical, Fertility, Doctors, Urologists
#      </p>
#      <p>
#       <h6>
#        61.
#        <a href="reviews_wV7wpc9uSZJy_OwPOdt4Dg.html">
#         Mitchell Plastic Surgery/Contours and Curves
#        </a>
#       </h6>
#       54 N Pecos, Henderson, NV
#       <br/>
#       Beauty &amp; Spas, Doctors, Medical Spas, Health &amp; Medical, Cosmetic Surgeons
#      </p>
#      <p>
#       <h6>
#        62.
#        <a href="reviews_6TNxoaTubyTNJ07MjXNTbw.html">
#         Modern Family Medicine
#        </a>
#       </h6>
#       7522 E 1st St, Scottsdale, AZ
#       <br/>
#       Osteopathic Physicians, Fitness &amp; Instruction, Active Life, Health &amp; Medical, Doctors, Acupuncture, Meditation Centers, Family Practice, Naturopathic/Holistic
#      </p>
#      <p>
#       <h6>
#        63.
#        <a href="reviews_S4kKHiAwHZXzZmvgjcfE8Q.html">
#         Moringa Natural Health Center
#        </a>
#       </h6>
#       13000 N 103rd Ave, Ste 74, Sun City, AZ
#       <br/>
#       IV Hydration, Pain Management, Acupuncture, Doctors, Naturopathic/Holistic, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        64.
#        <a href="reviews_BScPYpeOrVmDl23vnDfxjA.html">
#         Mountain Vista Pediatrics
#        </a>
#       </h6>
#       6301 Mountain Vista St, Henderson, NV
#       <br/>
#       Doctors, Pediatricians, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        65.
#        <a href="reviews_epy45cNXz4n7xnSBxjLmPQ.html">
#         Nature's Emporium
#        </a>
#       </h6>
#       16655 Yonge Street, Newmarket, ON
#       <br/>
#       Specialty Food, Health Markets, Fruits &amp; Veggies, Shopping, Restaurants, Food, Gluten-Free, Organic Stores, Grocery
#      </p>
#      <p>
#       <h6>
#        66.
#        <a href="reviews_GwO6xPKa2S-VOJdQSjWe1Q.html">
#         New Town Dentistry
#        </a>
#       </h6>
#       1532 Providence Rd S, Ste 220, Waxhaw, NC
#       <br/>
#       Health &amp; Medical, General Dentistry, Dentists, Cosmetic Dentists
#      </p>
#      <p>
#       <h6>
#        67.
#        <a href="reviews_gnmoot_IGqoK9v0QRmKYeQ.html">
#         Newman Chiropractic Center
#        </a>
#       </h6>
#       527 Shady Ave, Pittsburgh, PA
#       <br/>
#       Chiropractors, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        68.
#        <a href="reviews_tzCFo5of-bekZOfN_ggNNA.html">
#         NextCare Urgent Care
#        </a>
#       </h6>
#       5920 W. McDowell Road, Phoenix, AZ
#       <br/>
#       Doctors, Medical Centers, Urgent Care, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        69.
#        <a href="reviews_sp2hvV6RBWm4J3s2GVArXg.html">
#         North Phoenix Eye Care
#        </a>
#       </h6>
#       19235 N Cave Creek Rd, Ste 104, Phoenix, AZ
#       <br/>
#       Optometrists, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        70.
#        <a href="reviews_T_BmGLVAMPF9mp_W3WkjJA.html">
#         Nutrishop
#        </a>
#       </h6>
#       9555 S Eastern Ave, Ste 140, Las Vegas, NV
#       <br/>
#       Health Markets, Specialty Food, Food
#      </p>
#      <p>
#       <h6>
#        71.
#        <a href="reviews_NOagRrSGzpIwkhOyBqfdPw.html">
#         One Stop Nutrition
#        </a>
#       </h6>
#       15459 W Bell Rd, Ste 109, Surprise, AZ
#       <br/>
#       Health Markets, Juice Bars &amp; Smoothies, Specialty Food, Vitamins &amp; Supplements, Shopping, Food
#      </p>
#      <p>
#       <h6>
#        72.
#        <a href="reviews_i0S3M_DMFS3W55bMKkVmaw.html">
#         Pande Family Chiropractic
#        </a>
#       </h6>
#       32 Berwick Ave, Toronto, ON
#       <br/>
#       Chiropractors, Nutritionists, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        73.
#        <a href="reviews_R1dvisSeKw27ti-LkHTASg.html">
#         Paradise Reflexology And Massage
#        </a>
#       </h6>
#       7620 E Mckellips Rd, Ste 2, Scottsdale, AZ
#       <br/>
#       Massage Therapy, Health &amp; Medical, Reflexology, Traditional Chinese Medicine
#      </p>
#      <p>
#       <h6>
#        74.
#        <a href="reviews_OwK7gDIzZXumpQiQ8Cnb2A.html">
#         Phoenix Family Medical Clinic
#        </a>
#       </h6>
#       1108 W Indian School Rd, Ste B, Phoenix, AZ
#       <br/>
#       Family Practice, Health &amp; Medical, Doctors
#      </p>
#      <p>
#       <h6>
#        75.
#        <a href="reviews_BiSpQCtl7LFikBbfJmqslA.html">
#         Pure Vanity
#        </a>
#       </h6>
#       25101 N Lake Pleasant Pkwy, Ste 1315, Peoria, AZ
#       <br/>
#       Hair Removal, Day Spas, Beauty &amp; Spas, Medical Spas, Skin Care, Health &amp; Medical, Laser Hair Removal
#      </p>
#      <p>
#       <h6>
#        76.
#        <a href="reviews_Xe6TgtEdNXXkVo3NufocLA.html">
#         Rainsprings Dental Group and Orthodontics
#        </a>
#       </h6>
#       8035 S Rainbow Blvd, Ste 102, Las Vegas, NV
#       <br/>
#       General Dentistry, Cosmetic Dentists, Dentists, Orthodontists, Health &amp; Medical, Oral Surgeons
#      </p>
#      <p>
#       <h6>
#        77.
#        <a href="reviews_1pt6_WfVJdpb0Uq6HYKhzw.html">
#         Rejuve Health &amp; Wellness
#        </a>
#       </h6>
#       320 10 Street NW, Suite 201, Calgary, AB
#       <br/>
#       Weight Loss Centers, Health &amp; Medical, Eyelash Service, Day Spas, Massage, Beauty &amp; Spas
#      </p>
#      <p>
#       <h6>
#        78.
#        <a href="reviews_ON9iLGxFDeQln4iAlO7gkA.html">
#         Rhodes Ranch Fit Body Boot Camp
#        </a>
#       </h6>
#       6565 S Fort Apache Rd, Ste 170, Las Vegas, NV
#       <br/>
#       Boot Camps, Active Life, Weight Loss Centers, Fitness &amp; Instruction, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        79.
#        <a href="reviews_GP3r9MZ2Pt9cR7UHrx9lbQ.html">
#         Riverside Dental
#        </a>
#       </h6>
#       690 Queen Street E, Space B, Toronto, ON
#       <br/>
#       General Dentistry, Health &amp; Medical, Dentists
#      </p>
#      <p>
#       <h6>
#        80.
#        <a href="reviews_x7yHLG5a38FGYnhcwylekw.html">
#         Roehl T Pena MD
#        </a>
#       </h6>
#       7280 Azure Dr, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Doctors, Internal Medicine
#      </p>
#      <p>
#       <h6>
#        81.
#        <a href="reviews_KMGI7VvY9oacCsZKHAYIIw.html">
#         Ross' No Frills
#        </a>
#       </h6>
#       25 Photography Drive, Toronto, ON
#       <br/>
#       Health &amp; Medical, Pharmacy, Grocery, Food
#      </p>
#      <p>
#       <h6>
#        82.
#        <a href="reviews_htB_5GK6rLYynVnsS6eDlw.html">
#         Rouge Valley Health System - Rouge Valley Centenary
#        </a>
#       </h6>
#       2867 Ellesmere Road, Scarborough, ON
#       <br/>
#       Medical Centers, Hospitals, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        83.
#        <a href="reviews_yZWrk_OwNKUebksmNvMFvQ.html">
#         See Right Now With Timothy Perozek MD
#        </a>
#       </h6>
#       653 N Town Center Dr, Ste 212, Las Vegas, NV
#       <br/>
#       Laser Eye Surgery/Lasik, Doctors, Eyewear &amp; Opticians, Optometrists, Health &amp; Medical, Ophthalmologists, Shopping
#      </p>
#      <p>
#       <h6>
#        84.
#        <a href="reviews_YWHxxcAkjDp0X0SPtHl78Q.html">
#         Shahrzad Orona Nmd
#        </a>
#       </h6>
#       7517 S McClintock Dr, Tempe, AZ
#       <br/>
#       Doctors, Naturopathic/Holistic, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        85.
#        <a href="reviews_hxerbQpXB1hnDAaQ9uXYVA.html">
#         Silver Creek Family Dental
#        </a>
#       </h6>
#       9708 Gilespie St, Ste A-101, Las Vegas, NV
#       <br/>
#       Cosmetic Dentists, Pediatric Dentists, Periodontists, Health &amp; Medical, General Dentistry, Dentists
#      </p>
#      <p>
#       <h6>
#        86.
#        <a href="reviews_d5AFsS5BmfjVa32EP5XZtw.html">
#         Sina Nasri MD
#        </a>
#       </h6>
#       3150 N Tenaya Way, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Doctors
#      </p>
#      <p>
#       <h6>
#        87.
#        <a href="reviews_IDMkHKuwGmJCWv8V4lj8nQ.html">
#         Six Degrees Community Acupuncture
#        </a>
#       </h6>
#       204 Spadina Avenue, 2nd Floor, Toronto, ON
#       <br/>
#       Traditional Chinese Medicine, Beauty &amp; Spas, Acupuncture, Massage, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        88.
#        <a href="reviews_aIEfjonMB3daXlPDYTaucA.html">
#         Smith's Marketplace
#        </a>
#       </h6>
#       9710 W Skye Canyon Park Dr, Las Vegas, NV
#       <br/>
#       Food, Pharmacy, Traditional Clothing, Shopping, Fashion, Grocery, Home &amp; Garden, Health &amp; Medical, Home Decor
#      </p>
#      <p>
#       <h6>
#        89.
#        <a href="reviews_M497uyyzI4FkEptLTy7Ing.html">
#         South Health Campus
#        </a>
#       </h6>
#       4448 Front Street SE, Calgary, AB
#       <br/>
#       Hospitals, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        90.
#        <a href="reviews_QexQyTSKXuJqYPtV3Xhgdg.html">
#         Southwest Dermatology Center: Martin Safko, MD
#        </a>
#       </h6>
#       3150 N Tenaya Way, Ste 455, Las Vegas, NV
#       <br/>
#       Hair Removal, Dermatologists, Laser Hair Removal, Medical Spas, Doctors, Beauty &amp; Spas, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        91.
#        <a href="reviews_KQKUVoZjYE56GsG7DY1CpA.html">
#         Southwest Eye Institute
#        </a>
#       </h6>
#       8981 W Sahara Ave, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Ophthalmologists, Laser Eye Surgery/Lasik, Doctors
#      </p>
#      <p>
#       <h6>
#        92.
#        <a href="reviews_5_ggKetOZfILWGuoIBvGAw.html">
#         Southwest Medical Associates at Flamingo
#        </a>
#       </h6>
#       6330 W Flamingo Rd, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Medical Centers, Doctors
#      </p>
#      <p>
#       <h6>
#        93.
#        <a href="reviews_L6f2DKynvpUThYxXOND_Yw.html">
#         Soya Street
#        </a>
#       </h6>
#       8360 Kennedy Road, Markham, ON
#       <br/>
#       Shopping, Food, Specialty Food, Health Markets
#      </p>
#      <p>
#       <h6>
#        94.
#        <a href="reviews_A7jKgRVYQ_wCQjdGz8hd4Q.html">
#         Spire Health Club
#        </a>
#       </h6>
#       3927 East Indian School, Phoenix, AZ
#       <br/>
#       Health &amp; Medical, Gyms, Nutritionists, Active Life, Trainers, Fitness &amp; Instruction
#      </p>
#      <p>
#       <h6>
#        95.
#        <a href="reviews_58QoAy7ggzj8ukeJ8YmKFw.html">
#         Sprouts Farmers Market
#        </a>
#       </h6>
#       3365 E Tropicana Ave, Las Vegas, NV
#       <br/>
#       Grocery, Food, Specialty Food, Farmers Market, Fruits &amp; Veggies, Health Markets
#      </p>
#      <p>
#       <h6>
#        96.
#        <a href="reviews_TFt82fTODTFKPmRYycqTkw.html">
#         Star Pupil
#        </a>
#       </h6>
#       20201 N Scottdale Healthcare Dr, Ste 150, Scottsdale, AZ
#       <br/>
#       Shopping, Health &amp; Medical, Eyewear &amp; Opticians, Optometrists
#      </p>
#      <p>
#       <h6>
#        97.
#        <a href="reviews_NLzfI35ADqp259-rQLAVeg.html">
#         Steven H. Poulos, DDS
#        </a>
#       </h6>
#       9070 E Desert Cove Ave, Ste 105, Scottsdale, AZ
#       <br/>
#       Emergency Medicine, Health &amp; Medical, General Dentistry, Dentists, Doctors
#      </p>
#      <p>
#       <h6>
#        98.
#        <a href="reviews_h2FjTIv_U09fmy2xz8Pcpw.html">
#         Steven Rhodes, DDS
#        </a>
#       </h6>
#       501 South Rancho E29, Ste E29, Las Vegas, NV
#       <br/>
#       General Dentistry, Health &amp; Medical, Dentists, Cosmetic Dentists, Periodontists, Prosthodontists
#      </p>
#      <p>
#       <h6>
#        99.
#        <a href="reviews_AhLksuV3T-QM3gZOVlUhDw.html">
#         Stork Vision Chandler
#        </a>
#       </h6>
#       1600 W Chandler Blvd, Ste 230, Chandler, AZ
#       <br/>
#       Health &amp; Medical, Medical Centers
#      </p>
#      <p>
#       <h6>
#        100.
#        <a href="reviews_Rzr5s3EJVVxrvQNdQ0c9Xg.html">
#         Stoughton Hospital
#        </a>
#       </h6>
#       900 Ridge St, Stoughton, WI
#       <br/>
#       Hospitals, Urgent Care, Medical Centers, Health &amp; Medical, Counseling &amp; Mental Health, Rehabilitation Center
#      </p>
#      <p>
#       <h6>
#        101.
#        <a href="reviews_3rPEJXqLWjlcB2vk8f6Z6A.html">
#         Sun Valley Pediatric Dentistry
#        </a>
#       </h6>
#       1220 S Higley Rd, Ste 206, Mesa, AZ
#       <br/>
#       Dentists, Health &amp; Medical, Pediatric Dentists, Orthodontists, General Dentistry
#      </p>
#      <p>
#       <h6>
#        102.
#        <a href="reviews_R7-Art-yi73tWaRTuXXH7w.html">
#         Sunrise Dental Henderson
#        </a>
#       </h6>
#       1550 W Horizon Ridge Pkwy, Ste S, Henderson, NV
#       <br/>
#       General Dentistry, Dentists, Periodontists, Health &amp; Medical, Beauty &amp; Spas, Teeth Whitening
#      </p>
#      <p>
#       <h6>
#        103.
#        <a href="reviews_i85KV7ISWS85v526DL8dFg.html">
#         Sunrise Foot and Ankle
#        </a>
#       </h6>
#       4580 S Eastern Ave, Ste 30, Las Vegas, NV
#       <br/>
#       Podiatrists, Doctors, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        104.
#        <a href="reviews_yYDu8Agm64U5qhFEdabngw.html">
#         Surprise Family Medicine
#        </a>
#       </h6>
#       14239 W Bell Rd, Ste 225, Surprise, AZ
#       <br/>
#       Doctors, Family Practice, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        105.
#        <a href="reviews_oE-BWbZFMQeBZQaZklXuYw.html">
#         Tattoo Bill's
#        </a>
#       </h6>
#       9640 S Tryon St, Ste E, Charlotte, NC
#       <br/>
#       Doctors, Laser Hair Removal, Beauty &amp; Spas, Tattoo Removal, Health &amp; Medical, Hair Removal, Tattoo, Piercing
#      </p>
#      <p>
#       <h6>
#        106.
#        <a href="reviews_-NtaIhg7_yOl-d4o0VtMFw.html">
#         Tatum Pediatric Dentistry
#        </a>
#       </h6>
#       14640 N Tatum Blvd, Ste 11, Phoenix, AZ
#       <br/>
#       Pediatric Dentists, Health &amp; Medical, Doctors, Pediatricians, Dentists, General Dentistry
#      </p>
#      <p>
#       <h6>
#        107.
#        <a href="reviews_s5_DMJbYJWR2XgR1HDs9PA.html">
#         Teddy Sim - ChiropracTed
#        </a>
#       </h6>
#       8560 S Eastern Ave, Ste 150, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Chiropractors
#      </p>
#      <p>
#       <h6>
#        108.
#        <a href="reviews__v195T_1IQacWonyTdXcyg.html">
#         The Art of Massage
#        </a>
#       </h6>
#       2727 Selwyn Ave, Ste 205, Charlotte, NC
#       <br/>
#       Health &amp; Medical, Beauty &amp; Spas, Massage, Massage Therapy
#      </p>
#      <p>
#       <h6>
#        109.
#        <a href="reviews_CGpmN4ZDHJSOV4MXyK9FxA.html">
#         The Midwife Center For Birth &amp; Women's Health
#        </a>
#       </h6>
#       2831 Penn Ave, Pittsburgh, PA
#       <br/>
#       Health &amp; Medical, Midwives
#      </p>
#      <p>
#       <h6>
#        110.
#        <a href="reviews_A1PuwtCeDuoPye_ElwIfrg.html">
#         The Pain Center
#        </a>
#       </h6>
#       20333 N 19th Ave, Ste 100, Phoenix, AZ
#       <br/>
#       Health &amp; Medical, Sports Medicine, Anesthesiologists, Pain Management, Medical Centers, Orthopedists, Doctors
#      </p>
#      <p>
#       <h6>
#        111.
#        <a href="reviews_dloMNbqt1o5YBAq1N1lI6w.html">
#         The Skin Klinic
#        </a>
#       </h6>
#       73 Warren Road, Toronto, ON
#       <br/>
#       Health &amp; Medical, Skin Care, Medical Spas, Beauty &amp; Spas
#      </p>
#      <p>
#       <h6>
#        112.
#        <a href="reviews_4B4e-0_tk7MzESWgVs7eAg.html">
#         Trobough Dental
#        </a>
#       </h6>
#       8440 W Lake Mead Blvd, Ste 207, Las Vegas, NV
#       <br/>
#       Dentists, Endodontists, General Dentistry, Health &amp; Medical, Cosmetic Dentists
#      </p>
#      <p>
#       <h6>
#        113.
#        <a href="reviews_3QFyMR9Iz3B3UUAWAUrgxw.html">
#         Ultra Smile Dentistry
#        </a>
#       </h6>
#       1423 S Higley Rd, Ste 123, Mesa, AZ
#       <br/>
#       General Dentistry, Dentists, Cosmetic Dentists, Health &amp; Medical, Pediatric Dentists
#      </p>
#      <p>
#       <h6>
#        114.
#        <a href="reviews_o0BtbWwcUwvNHoAPx_eDBg.html">
#         United Blood Services - Chandler
#        </a>
#       </h6>
#       1989 W. Elliot Road, #32, Chandler, AZ
#       <br/>
#       Health &amp; Medical, Community Service/Non-Profit, Medical Centers, Blood &amp; Plasma Donation Centers, Local Services
#      </p>
#      <p>
#       <h6>
#        115.
#        <a href="reviews_lzLNIWu2Cj88u2QkGH4i3A.html">
#         University Sports Medicine
#        </a>
#       </h6>
#       15810 S 45th St, Ste 101, Phoenix, AZ
#       <br/>
#       Sports Medicine, Health &amp; Medical, Doctors, Family Practice
#      </p>
#      <p>
#       <h6>
#        116.
#        <a href="reviews_oBsbQlzSdK7XozGE6v1F4w.html">
#         University of Pittsburgh Medical Center
#        </a>
#       </h6>
#       200 Lothrop St, Pittsburgh, PA
#       <br/>
#       Medical Centers, Doctors, Hospitals, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        117.
#        <a href="reviews_rhdMlNeDd5BN1Ou2EFIJOA.html">
#         Village Family Health Team
#        </a>
#       </h6>
#       171 E Liberty Street, Unit 102, Toronto, ON
#       <br/>
#       Doctors, Health &amp; Medical, Family Practice
#      </p>
#      <p>
#       <h6>
#        118.
#        <a href="reviews_f7Fg_f9OsvHnDV9slIh_qw.html">
#         Visionworks
#        </a>
#       </h6>
#       7000 E Mayo Blvd, Bldg 4, Phoenix, AZ
#       <br/>
#       Eyewear &amp; Opticians, Optometrists, Health &amp; Medical, Shopping
#      </p>
#      <p>
#       <h6>
#        119.
#        <a href="reviews_AaFmfvnszVv1CUira_xZPA.html">
#         Women's Cancer Center Of Nevada
#        </a>
#       </h6>
#       3131 La Canada St, Ste 241, Las Vegas, NV
#       <br/>
#       Health &amp; Medical, Doctors, Oncologist
#      </p>
#      <p>
#       <h6>
#        120.
#        <a href="reviews_gestVQlI_Bv7DN-FZkvEBw.html">
#         YS Canadian Laser
#        </a>
#       </h6>
#       3201 Yonge Street, Toronto, ON
#       <br/>
#       Beauty &amp; Spas, Skin Care, Health &amp; Medical, Laser Hair Removal, Medical Spas, Doctors, Massage Therapy, Tattoo Removal, Day Spas, Makeup Artists, Nail Salons, Hair Removal
#      </p>
#      <p>
#       <h6>
#        121.
#        <a href="reviews_c9eiZmPuSu9XRqSaw4mhUQ.html">
#         Yonge &amp; Front Dental Clinic
#        </a>
#       </h6>
#       33 Yonge Street, Toronto, ON
#       <br/>
#       Dental Hygienists, Cosmetic Dentists, General Dentistry, Dentists, Orthodontists, Periodontists, Health &amp; Medical
#      </p>
#      <p>
#       <h6>
#        122.
#        <a href="reviews_vI36C9W73Wn46fQ6tMZngw.html">
#         Your Good Health Stores
#        </a>
#       </h6>
#       355 Queen St W, Toronto, ON
#       <br/>
#       Food, Health Markets, Specialty Food
#      </p>
#      <div class="footer">
#       Content on this site is posted for teaching purposes only.
#      </div>
#      <!-- Bootstrap core JavaScript
#     ================================================== -->
#      <!-- Placed at the end of the document so the pages load faster -->
#      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#      </script>
#      <script src="assets/js/bootstrap.min.js">
#      </script>
#      <script src="assets/js/retina-1.1.0.js">
#      </script>
#      <script src="assets/js/jquery.hoverdir.js">
#      </script>
#      <script src="assets/js/jquery.hoverex.min.js">
#      </script>
#      <script src="assets/js/jquery.isotope.min.js">
#      </script>
#      <script src="assets/js/custom.js">
#      </script>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
#
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="noindex" name="robots"/>
#   <meta content="Content on this site is posted for teaching purposes only. Original data is from yelp.com" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Yalp — AZ Dental Wellness
#   </title>
#   <link href="images/favicon.ico" rel="shortcut icon"/>
#   <!-- Bootstrap core CSS -->
#   <link href="assets/css/bootstrap.css" rel="stylesheet"/>
#   <!-- Custom styles for this template -->
#   <link href="assets/css/style.css" rel="stylesheet"/>
#   <link href="assets/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="assets/js/modernizr.js">
#   </script>
#  </head>
#  <body>
#   <div class="container mtb">
#    <div class="row">
#     <div class="col-md-12">
#      <h3 class="info">
#       Yalp — AZ Dental Wellness
#      </h3>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-10" name="main">
#      <p class="details">
#       <img src="images/location.png" width="16px"/>
#       3014 N Hayden Rd, Ste 104, Scottsdale, AZ
#      </p>
#      <p class="details">
#       Description: Dentists, Teeth Whitening, General Dentistry, Pediatric Dentists, Endodontists, Cosmetic Dentists, Beauty &amp; Spas, Health &amp; Medical
#       <br/>
#       Opening hours today: 10:00 - 17:00
#      </p>
#      <h5>
#       Recommended reviews for this business:
#      </h5>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-06-27
#        </b>
#        by
#        <i>
#         Nadine Cooper
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I have so many good things to say about this place. I needed a cleaning and a filling so I decided to do the part I was dreading more, the filling. But Dr. Carlos had the "magic touch" and I felt no pain at all and the process was over way faster than I thought it would be. Next, I came in for my cleaning and it was with Dr. Mandap. She was very friendly and after my cleaning she was very patient and took the time to answer all of the questions I had about my teeth, gums, etc. and gave me a lot of good tips on my personal dental care. The office has a cool futuristic look to it as well, and the receptionist is always accommodating. Glad I finally found a great dentist in the Scottsdale area. Thank you AZ Dental Wellness!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-06-20
#        </b>
#        by
#        <i>
#         Mariano Slowe
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I found them to be highly skilled and an experienced dentistry that was willing to work with me and put together a reasonable plan to take care of all of my dental needs without having to have a financial advisor : ). The atmosphere is the furthest thing from the business only approach that I received from other practices, from the receptionist to the dental assistant and from the doctor himself they all showed a level comfort and genuine care that made me feel like I was not just a patient but like I was a part of their family. For real for real... they have been the best!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-05-24
#        </b>
#        by
#        <i>
#         Richard Wilson
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Where do I even begin? This office has been so incredibly good to my family! I love the staff, everyone is so sweet and Dr. Carlos is such a humble guy! A couple of us needed some work done but for me specifically they were able to get my smile back for a really great price. Cheaper than anywhere else I've looked into. Usually places being cheaper may be a bit skeptical but this office does inexpensive quality work. The office is clean, organized and has a great peaceful environment. I really can't thank them enough for everything they've done for us! We will definitely be back for regular cleanings and we most definitely would highly recommend their services!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-02-27
#        </b>
#        by
#        <i>
#         Martin Cummings
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I went in because I had toothache and needed a cleaning. They were really friendly, and very prompt with fixing my small cavity!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-02-01
#        </b>
#        by
#        <i>
#         Charles Logiudice
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Found a new dental office. This place is amazing. The people who work here are very pleasant. I love the decor too. The dentist is excellent!!!!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-01-10
#        </b>
#        by
#        <i>
#         Muoi Kitamura
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Dr. Carlos is always on top of things, I've never had to wait long before any appointments. He is the nicest and most sincere doctor I have ever seen regularly. This man is clearly a professional and knows what he is doing. All of the staff members are extremely polite and helpful. If you live in the East Valley then this office is the perfect location.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-01-10
#        </b>
#        by
#        <i>
#         Frank Blevins
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Dr. Carlos and the staff were very friendly. The office was very nice with a new modern look! Got work done and am looking forward to visiting again!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-01-09
#        </b>
#        by
#        <i>
#         Edward Sung
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Love these guys! Had a chip in my tooth and no time to spare because I had to work. They took care of me right away and it was seamless. Thank you guys!!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-10-12
#        </b>
#        by
#        <i>
#         Marcella Jackson
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I just found this office in Scottsdale and they're really good. They take their time explaining every procedure and the results are amazing. If you're looking for a dental office that cares about you and not just about the dollar come here.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-09-07
#        </b>
#        by
#        <i>
#         Jack Shephard
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Dr. Mandap has been my dentist for many years and I wouldn't have it any other way. Everything is always quick and easy. Truly the best and nicest dentist I've had! And this new office is also very beautiful!
#       </p>
#      </div>
#      <div class="footer">
#       Content on this site is posted for teaching purposes only.
#      </div>
#      <!-- Bootstrap core JavaScript
#     ================================================== -->
#      <!-- Placed at the end of the document so the pages load faster -->
#      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#      </script>
#      <script src="assets/js/bootstrap.min.js">
#      </script>
#      <script src="assets/js/retina-1.1.0.js">
#      </script>
#      <script src="assets/js/jquery.hoverdir.js">
#      </script>
#      <script src="assets/js/jquery.hoverex.min.js">
#      </script>
#      <script src="assets/js/jquery.isotope.min.js">
#      </script>
#      <script src="assets/js/custom.js">
#      </script>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
#
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="noindex" name="robots"/>
#   <meta content="Content on this site is posted for teaching purposes only. Original data is from yelp.com" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Yalp — ActiveForever
#   </title>
#   <link href="images/favicon.ico" rel="shortcut icon"/>
#   <!-- Bootstrap core CSS -->
#   <link href="assets/css/bootstrap.css" rel="stylesheet"/>
#   <!-- Custom styles for this template -->
#   <link href="assets/css/style.css" rel="stylesheet"/>
#   <link href="assets/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="assets/js/modernizr.js">
#   </script>
#  </head>
#  <body>
#   <div class="container mtb">
#    <div class="row">
#     <div class="col-md-12">
#      <h3 class="info">
#       Yalp — ActiveForever
#      </h3>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-10" name="main">
#      <p class="details">
#       <img src="images/location.png" width="16px"/>
#       9299 W Olive Ave, Ste 604, Peoria, AZ
#      </p>
#      <p class="details">
#       Description: Medical Supplies, Food, Health Markets, Physical Therapy, Health &amp; Medical, Specialty Food, Shopping, Home Health Care
#       <br/>
#       Opening hours today: 7:30 - 17:30
#      </p>
#      <h5>
#       Recommended reviews for this business:
#      </h5>
#      <div class="review">
#       <p class="review-top">
#        <b>
# ...
#         Reviewed on 2017-04-24
#        </b>
#        by
#        <i>
#         Joseph Myles
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Yuliya is such a nice person and I felt so incredible comfortable going to her! She informed med well about the procedure and took care of me. I can see improvement after first session! I would definitely recommend this place because of the professionalism shown! :)
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-04-17
#        </b>
#        by
#        <i>
#         Larry Cortez
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I went for the first time to do laser hair removal on my upper lip, and Yulia is the most pleasent person to deal with. She gave me honest feed back and she really educates you before you buy. She is so sweet and genuine. Going to use her for the next treatments!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2016-09-23
#        </b>
#        by
#        <i>
#         Dina Hagler
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I had a wonderful spa experience at Canadian Laser Spa. The place is very warm and inviting. I came in for a facial and ended up getting a microdermabrasion treatment as well. I found Yuliya to be very knowledgeable and easy to talk to. The experience was very relaxing and enjoyable. Just what I needed. Can't wait to book my next appointment!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2016-09-19
#        </b>
#        by
#        <i>
#         Sonja Hedgepeth
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        A wonderful treatment, makes you leave feeling very confident and fresh. Yuliya gives a very pleasant feel with her services. I definitely recommend this clinic.
#       </p>
#      </div>
#      <div class="footer">
#       Content on this site is posted for teaching purposes only.
#      </div>
#      <!-- Bootstrap core JavaScript
#     ================================================== -->
#      <!-- Placed at the end of the document so the pages load faster -->
#      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#      </script>
#      <script src="assets/js/bootstrap.min.js">
#      </script>
#      <script src="assets/js/retina-1.1.0.js">
#      </script>
#      <script src="assets/js/jquery.hoverdir.js">
#      </script>
#      <script src="assets/js/jquery.hoverex.min.js">
#      </script>
#      <script src="assets/js/jquery.isotope.min.js">
#      </script>
#      <script src="assets/js/custom.js">
#      </script>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="noindex" name="robots"/>
#   <meta content="Content on this site is posted for teaching purposes only. Original data is from yelp.com" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Yalp — Yonge &amp; Front Dental Clinic
#   </title>
#   <link href="images/favicon.ico" rel="shortcut icon"/>
#   <!-- Bootstrap core CSS -->
#   <link href="assets/css/bootstrap.css" rel="stylesheet"/>
#   <!-- Custom styles for this template -->
#   <link href="assets/css/style.css" rel="stylesheet"/>
#   <link href="assets/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="assets/js/modernizr.js">
#   </script>
#  </head>
#  <body>
#   <div class="container mtb">
#    <div class="row">
#     <div class="col-md-12">
#      <h3 class="info">
#       Yalp — Yonge &amp; Front Dental Clinic
#      </h3>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-10" name="main">
#      <p class="details">
#       <img src="images/location.png" width="16px"/>
#       33 Yonge Street, Toronto, ON
#      </p>
#      <p class="details">
#       Description: Dental Hygienists, Cosmetic Dentists, General Dentistry, Dentists, Orthodontists, Periodontists, Health &amp; Medical
#       <br/>
#       Opening hours today: 9:00 - 20:00
#      </p>
#      <h5>
#       Recommended reviews for this business:
#      </h5>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-04-17
#        </b>
#        by
#        <i>
#         Susan Paul
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="4-star" src="images/stars-4.png"/>
#       </p>
#       <p class="text">
#        I did a lot of research for different dental offices, and my research definitely paid off! 1. There is NEVER a wait (I have been here three times in the past 2 months, both my friends have had appointments, and there have never been any waits for longer than 5 minutes) 2. They have ODA pricing which is what most dental plans will cover. Despite the fact that this office is in Toronto, there is no random other superficial up-charges for normal services. (This was the main reason I initially chose this dentist). 3. They do an excellent job! My teeth were cleaned really well, the hygienist (who's name escapes me, but she was fantastic) was so friendly. They also run specials and promos (I got my annual exam and teeth cleaning and they threw in a free whitening session). 4. Appointments are super easy and correspondence is super quick! Their secretary Stacey does a great job to help fit appointments in ASAP and at times that work for you. 5. They have after work and weekend hours! I have officially made the switch to this super convenient and awesome dental office!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-11-25
#        </b>
#        by
#        <i>
#         Craig Hull
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        I came from the US to do my teeth here. Wonderful staff (thanks Gelareh!) and Dr. Man was awesome! Very professional, clean, and helpful. I'll definitely be coming back!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-07-11
#        </b>
#        by
#        <i>
#         Brian Lowers
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        The staff is amazing, obviously customer service and satisfaction is a priority for them. Paola is incredible, very professional and friendly, as is everyone else. They clearly focus on your best interest, and not trying to make a quick buck from their patients. Location is very convenient too, right by Union Station and close to work for those in the Financial district. Also, they are very punctual and don't keep you waiting and wasting your time like other clinics. I would highly recommend them to anyone in the area.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2015-08-12
#        </b>
#        by
#        <i>
#         Reginald Williams
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Gelareh did such an amazing cleaning for me the other day! No discomfort, and my teeth feel so clean!! Great chair-side manner. Dr. Hobbs is highly professional, and spoke patiently and confidently to my questions and concerns (plus, it's pretty neat to say my dentist is on TV!). Definitely made a trip to the dentist an enjoyable experience.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2015-06-05
#        </b>
#        by
#        <i>
#         Clarence Caldwell
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Friendly staff that is both very professional and knowledgeable. I had pleasure to have dealt with Gelareh the hygienist, Layla the assistant, Paola the receptionist and Dr. Hobbs. All of them individually are everything and more that one could expect from their specific roles, but together make a trip to the dentist feel like visiting a loving family. You can rest assured that if you need any dental work done this office has got you covered on all fronts.
#       </p>
#      </div>
#      <div class="footer">
#       Content on this site is posted for teaching purposes only.
#      </div>
#      <!-- Bootstrap core JavaScript
#     ================================================== -->
#      <!-- Placed at the end of the document so the pages load faster -->
#      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#      </script>
#      <script src="assets/js/bootstrap.min.js">
#      </script>
#      <script src="assets/js/retina-1.1.0.js">
#      </script>
#      <script src="assets/js/jquery.hoverdir.js">
#      </script>
#      <script src="assets/js/jquery.hoverex.min.js">
#      </script>
#      <script src="assets/js/jquery.isotope.min.js">
#      </script>
#      <script src="assets/js/custom.js">
#      </script>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
#
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="noindex" name="robots"/>
#   <meta content="Content on this site is posted for teaching purposes only. Original data is from yelp.com" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Yalp — Your Good Health Stores
#   </title>
#   <link href="images/favicon.ico" rel="shortcut icon"/>
#   <!-- Bootstrap core CSS -->
#   <link href="assets/css/bootstrap.css" rel="stylesheet"/>
#   <!-- Custom styles for this template -->
#   <link href="assets/css/style.css" rel="stylesheet"/>
#   <link href="assets/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="assets/js/modernizr.js">
#   </script>
#  </head>
#  <body>
#   <div class="container mtb">
#    <div class="row">
#     <div class="col-md-12">
#      <h3 class="info">
#       Yalp — Your Good Health Stores
#      </h3>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-10" name="main">
#      <p class="details">
#       <img src="images/location.png" width="16px"/>
#       355 Queen St W, Toronto, ON
#      </p>
#      <p class="details">
#       Description: Food, Health Markets, Specialty Food
#      </p>
#      <h5>
#       Recommended reviews for this business:
#      </h5>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2018-02-04
#        </b>
#        by
#        <i>
#         Theresa Meade
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="5-star" src="images/stars-5.png"/>
#       </p>
#       <p class="text">
#        Always a great place to get all your supplements for a good price. They don't rip you off, despite the negative reviews...I've been to GNC and other organic supplement stores and none are as reasonable priced as this one. They even order in a product if they don't carry it in store. Love this place!
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-11-24
#        </b>
#        by
#        <i>
#         Ernest Doucett
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="1-star" src="images/stars-1.png"/>
#       </p>
#       <p class="text">
#        WAY OVERPRICED. Go to Healthy Planet, or other natural health product stores nearby instead, these guys are insane with the prices! I was only in town to pick up a few refills. Only this brunette chick of medium build was in the store, and on the phone, didn't see me or acknowledge me. I heard her literally yelling at whoever's on the other end, very rude and unprofessional. I walked to the cash register to be checked out, where she finally saw me and got off the phone. Then she kept going on and on about something I don't need and have no interest in knowing about, she was being annoying and pushy with her verbal diarrhea. I would NEVER want to come back again.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-03-15
#        </b>
#        by
#        <i>
#         Carlos Stone
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="4-star" src="images/stars-4.png"/>
#       </p>
#       <p class="text">
#        I'm surprised at the negative reviews. I go here for athletic supplements, and the sport section has respected brand name products at prices lower than online. If you live, work, or use a gym nearby it's worth visiting.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2017-03-06
#        </b>
#        by
#        <i>
#         Robert Bell
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="1-star" src="images/stars-1.png"/>
#       </p>
#       <p class="text">
#        I've came in to this store twice now to purchase some items but had bad experiences both times. The sales people are pushy and condescending and the way they kept recommending products (that had nothing to do with what I came in for) really put me off. Both times I went here, I felt really uncomfortable and just wanted to get out ASAP. There are a lot of other natural health product stores nearby that are so much better and not overpriced as this one.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2016-01-08
#        </b>
#        by
#        <i>
#         Maurice Lee
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="1-star" src="images/stars-1.png"/>
#       </p>
#       <p class="text">
#        Most definitely not impressed with this place. The salesperson was rude and pushy. I came in to buy chlorophyll, and in the process was insulted with uncalled for remarks about my breakout. Oh and over priced too.
#       </p>
#      </div>
#      <div class="review">
#       <p class="review-top">
#        <b>
#         Reviewed on 2011-09-27
#        </b>
#        by
#        <i>
#         Thomas Kendrick
#        </i>
#       </p>
#       <p class="stars">
#        <img alt="2-star" src="images/stars-2.png"/>
#       </p>
#       <p class="text">
#        If a place like this can afford the rent on this expensive piece of real estate, they are probably ripping you off. I'm not a huge fan of 'natural' health food stores. Because if you eat right, isn't that the most natural way to eat? The sales staff, like others have said, go on and on about the benefits of different products. As a pharmacist, I found it odd to watch the sales person try to describe absorption when she just isn't trained to do that. I find the whole experience a little uncomfortable. So, now I'm going online to try to find some more natural shampoos and soaps. Yes, I do like some things that are 'natural', but in the end, Death is natural, so give me the chemicals, if i need them.
#       </p>
#      </div>
#      <div class="footer">
#       Content on this site is posted for teaching purposes only.
#      </div>
#      <!-- Bootstrap core JavaScript
#     ================================================== -->
#      <!-- Placed at the end of the document so the pages load faster -->
#      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#      </script>
#      <script src="assets/js/bootstrap.min.js">
#      </script>
#      <script src="assets/js/retina-1.1.0.js">
#      </script>
#      <script src="assets/js/jquery.hoverdir.js">
#      </script>
#      <script src="assets/js/jquery.hoverex.min.js">
#      </script>
#      <script src="assets/js/jquery.isotope.min.js">
#      </script>
#      <script src="assets/js/custom.js">
#      </script>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# Create database for category B, Automotive reviews

# %%
# extract Automotive reviews
url = endpoint + 'automotive_list.html'
review_list = extract_data(url)
create_database('Category_B.csv', review_list)

# %%
dataset_A = pd.read_csv('Category_A.csv')
dataset_A.shape
# Out:
# (1450, 2)

# %%
def preprocess_text(text):
    # this function takes a text as an input 
    # tokenizes the text into individual tokens
    tokenized_words = word_tokenize(text)
    # removes the punctuation
    normalised_words = [word for word in tokenized_words if word.isalpha()]
    
    # removes all the stop words
    return [word for word in normalised_words if word.lower() not in stopwords.words('english')]

# %% [markdown]
# TASK 2 cross validation

# %% [markdown]
# task 3 hold out testing , i.e. train on data from one category and test on data from another.

# %%
def preprocess_reviews():
    for column in dataset_A:
        preprocess_text(dataset_A[column])

# %%
preprocess_reviews()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2584e6bfb0c7> in <module>()
# ----> 1 preprocess_reviews()
#
# <ipython-input-9-1690eb3a75e3> in preprocess_reviews()
#       1 def preprocess_reviews():
#       2     for column in dataset_A:
# ----> 3         preprocess_text(dataset_A[column])
#
# <ipython-input-8-e07c9817a957> in preprocess_text(text)
#       2     # this function takes a text as an input
#       3     # tokenizes the text into individual tokens
# ----> 4     tokenized_words = word_tokenize(text)
#       5     # removes the punctuation
#       6     normalised_words = [word for word in tokenized_words if word.isalpha()]
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1239         Given a text, returns a list of the sentences in that text.
#    1240         """
# -> 1241         return list(self.sentences_from_text(text, realign_boundaries))
#    1242
#    1243     def debug_decisions(self, text):
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1279         if realign_boundaries:
#    1280             slices = self._realign_boundaries(text, slices)
# -> 1281         for sl in slices:
#    1282             yield (sl.start, sl.stop)
#    1283
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1320         """
#    1321         realign = 0
# -> 1322         for sl1, sl2 in _pair_iter(slices):
#    1323             sl1 = slice(sl1.start + realign, sl1.stop)
#    1324             if not sl2:
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     311     """
#     312     it = iter(it)
# --> 313     prev = next(it)
#     314     for el in it:
#     315         yield (prev, el)
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1293     def _slices_from_text(self, text):
#    1294         last_break = 0
# -> 1295         for match in self._lang_vars.period_context_re().finditer(text):
#    1296             context = match.group() + match.group('after_tok')
#    1297             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
